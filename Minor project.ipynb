# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
a=pd.read_csv(r"G:\StudentsPerformance.csv",sep=',')
a.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
a.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
a.shape
# Out:
# (1000, 8)

# %%
a.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
a.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
a.columns = a.columns.str.replace(' ', '_')
a.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
a.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental_level_of_education    1000
# lunch                          1000
# test_preparation_course        1000
# math_score                     1000
# reading_score                  1000
# writing_score                  1000
# dtype: int64

# %%
a.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
a.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.countplot(x="gender", data=a)

# %%
a.groupby('gender').mean().plot(kind='barh')

# %%
# %matplotlib inline
a.reading_score.plot(kind='hist',color='pink')

# %%
# %matplotlib inline
a.writing_score.plot(kind='hist',color='purple')

# %%
a['reading_score'].std(),a['writing_score'].std()
# Out:
# (14.60019193725222, 15.195657010869642)

# %%
import matplotlib.pyplot as plotter
x='reading_score','writing_score','math_score'
y=[100,100,100] #Taking maximum values of reading_score,writing_score,math_score
figureObject, axesObject = plotter.subplots()
axesObject.pie(y, labels=x, autopct='%1.2f',startangle=90)
axesObject.axis('equal')
plotter.show()

# %%
sns.countplot(x="parental_level_of_education", data=a, hue = a.gender)

# %%
a.math_score.value_counts()
# Out:
# 65    36
# 62    35
# 59    32
# 69    32
# 73    27
#       ..
# 22     1
# 19     1
# 18     1
# 8      1
# 0      1
# Name: math_score, Length: 81, dtype: int64

# %%
sns.distplot(a['math_score'],kde=True,bins=30, hist=False)

# %%
sns.distplot(a['math_score'])

# %%
sns.distplot(a['writing_score'])

# %%
sns.distplot(a['reading_score'])

# %%
a.parental_level_of_education.unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
a.parental_level_of_education.value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental_level_of_education, dtype: int64

# %%
a.parental_level_of_education.value_counts().plot(kind='bar')

# %%
sns.countplot(x="parental_level_of_education", data=a, hue = 'test_preparation_course')

# %%
sns.distplot(a['math_score'],kde=False,hist=True,bins=11,hist_kws=dict(color="pink", linewidth=1))
sns.distplot(a['writing_score'],kde=False,hist=True,bins=11,hist_kws=dict(color="b", linewidth=1))
sns.distplot(a['reading_score'],kde=False,hist=True,bins=11,hist_kws=dict(color="y", linewidth=1))

# %%
sns.kdeplot(a['reading_score'],shade=True)
sns.kdeplot(a['writing_score'],shade=True)

# %%
sns.countplot(x="math_score", data=a, hue = a.gender)

# %%
sns.countplot(x='parental_level_of_education', data=a, hue = a['race/ethnicity'])

# %%
sns.countplot(x="reading_score", data=a, hue=a['race/ethnicity'])

# %%
sns.countplot(x="lunch", data=a, hue ='math_score')

# %%
a.corr()
# Out:
#                math_score  reading_score  writing_score
# math_score       1.000000       0.817580       0.802642
# reading_score    0.817580       1.000000       0.954598
# writing_score    0.802642       0.954598       1.000000

# %%
sns.heatmap(a.corr())
